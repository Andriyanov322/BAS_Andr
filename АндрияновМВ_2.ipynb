# %% [markdown]
# #Таблица греческих букв
# ##Таблица греческих букв
# ###Таблица греческих букв
#
# \begin{array}{ccc}
# \text{Заглавная}&\text{Cтрочная}
# &\text{Название}\\
# 1. \text{Α}&{α}&альфа\\
# 2. \text{Β}&{β}&бета (вита)\\
# 3. \text{Γ}&{γ}&гамма \\
# 4. \text{Δ}&{δ}&дельта \\
# 5. \text{Ε}&{ϵ}&эпсилон \\
# 6. \text{Ζ}&{ζ}&дзета (зита) \\
# 7. \text{Η}&{η}&эта (ита) \\
# 8. \text{Θ}&{θ}&тета (фита)\\
# 9. \text{Ι}&{ι}&йота\\
# 10. \text{Κ}&{κ}&каппа   \\
# 11. \text{Λ}&{λ}&лямбда (лямда) \\
# 12. \text{M}&{μ}&мю (ми) \\
# 13. \text{Ν}&{ν}&ню (ни)  \\
# 14. \text{Ξ}&{ξ}&кси  \\
# 15. \text{O}&{o}&омикрон \\
# 16. \text{Π}&{π}&пи  \\
# 17. \text{Ρ}&{ρ}&ро   \\
# 18. \text{Σ}&{σ}&сигма   \\
# 19. \text{Τ}&{τ}&тау (тав)  \\
# 20. \text{Υ}&{υ}&ипсилон   \\
# 21. \text{Φ}&{ϕ}&фи  \\
# 22. \text{Χ}&{χ}&хи   \\
# 23. \text{Ψ}&{ψ}&пси   \\
# 24. \text{Ω}&{ω}&омега  \\
#  \end{array}
#
# Формула нормального распределения
#
# $${\displaystyle f(x)={\frac {1}{\sigma {\sqrt {2\pi }}}}e^
# {-{\frac {1}{2}}\left({\frac {x-\mu }{\sigma }}\right)^{2}}}$$
